# %% [markdown]
# # build-vega-docset
#
# > Converts a built copy of the vega static Jekyll site to a docset directory

# %% [markdown]
# 1. Clone `vega` as a sibling folder of this repository using the changes from [this PR](https://github.com/vega/vega/pull/3280)
# 2. In that directory, run `yarn install && yarn build && yarn docs:static`
# 3. In your python virtual environment, add these dependencies: `pip install -r requirements.txt`
# 4. Using Jupyter is optional, but recommended for ease of debugging
#
# Note: To debug the docset, rename it to a plain directory, then use SQLite browser to inspect the contents [link](https://sqlitebrowser.org/dl/)

# %%
# Make a folder to hold a copy of the built site
# !mkdir vega-docs
# Out:
# mkdir: cannot create directory ‘vega-docs’: File exists

# %%
# initial import of built site assets
# !rsync -r ../vega/docs/_site/* ./vega-docs

# %%
import glob
import os
from urllib.parse import quote
from os import path

import sqlite3

from bs4 import BeautifulSoup
# from bs4.element import NavigableString

# %%
DEBUG = True

# %%
DOCSET_NAME = 'vega'

# %%
DOCSET_PATH = f"{DOCSET_NAME}.docset/Contents/Resources/Documents/"

# %%
# Create a folder to hold your docset info
# !mkdir -p $DOCSET_PATH

# %%
VEGA_DOCSET = f"{DOCSET_NAME}.docset"
PLIST_PATH = f"{DOCSET_NAME}.docset/Contents/Info.plist"
SQLITE_PATH = f"{DOCSET_NAME}.docset/Contents/Resources/docSet.dsidx"

# %%
# Create Info.plist
docsetIndex = '''<?xml version="1.0" encoding="UTF-8"?>
<plist version="1.0">
  <dict>
    <key>CFBundleIdentifier</key>
    <string>vega</string>
    <key>CFBundleName</key>
    <string>Vega</string>
    <key>DocSetPlatformFamily</key>
    <string>vega</string>
    <key>isDashDocset</key>
    <true />
    <key>isJavaScriptEnabled</key>
    <true/>
    <key>dashIndexFilePath</key>
    <string>./index.html</string>
    <key>DashDocSetFallbackURL</key>
    <string>https://vega.github.io/vega/</string>
    <key>DashDocSetPlayURL</key>
    <string>https://vega.github.io/editor/#/custom/vega/</string>
    <key>DashDocSetFamily</key>
    <string>dashtoc</string>
  </dict>
</plist>
'''

with open('vega.docset/Contents/Info.plist', 'w') as fp:
    fp.write(docsetIndex)

# %%
# string to handle with replacement
DOCSET_BASE = 'DOCSET_BASE_TO_REPLACE'

def getDepthString(depth):
    return '.' + depth * "/.."


def update_relative_paths(filename):
    with open(filename) as fp:
        text = fp.read()
        
    depth = len(filename.split('/')) - 2
    depthString = getDepthString(depth)

    return text.replace(DOCSET_BASE, depthString)

# %%
# Convert absolute to relative URLs
matches = glob.glob(f"vega-docs/**/*.html", recursive=True)
print(len(matches))
# now let's clean up the source files
for name in matches:
    if DEBUG:
        print('Moving relative urls', name)
    processed = update_relative_paths(name)
    with open(name, 'w') as fp:
        fp.write(processed)
# Out:
# 192
# Moving relative urls vega-docs/index.html
# Moving relative urls vega-docs/usage/index.html
# Moving relative urls vega-docs/usage/interpreter/index.html
# Moving relative urls vega-docs/usage/internet-explorer/index.html
# Moving relative urls vega-docs/about/index.html
# Moving relative urls vega-docs/about/research/index.html
# Moving relative urls vega-docs/about/video/index.html
# Moving relative urls vega-docs/about/projects/index.html
# Moving relative urls vega-docs/about/vega-and-d3/index.html
# Moving relative urls vega-docs/about/code-of-conduct/index.html
# Moving relative urls vega-docs/docs/index.html
# Moving relative urls vega-docs/docs/schemes/index.html
# Moving relative urls vega-docs/docs/event-streams/index.html
# Moving relative urls vega-docs/docs/types/index.html
# Moving relative urls vega-docs/docs/axes/index.html
# Moving relative urls vega-docs/docs/marks/index.html
# Moving relative urls vega-docs/docs/marks/shape/index.html
# Moving relative urls vega-docs/docs/marks/rect/index.html
# Moving relative urls vega-docs/docs/marks/trail/index.html
# Moving relative urls vega-docs/docs/marks/area/index.html
# Moving relative urls vega-docs/docs/marks/group/index.html
# Moving relative urls vega-docs/docs/marks/path/index.html
# Moving relative urls vega-docs/docs/marks/symbol/index.html
# Moving relative urls vega-docs/docs/marks/image/index.html
# Moving relative urls vega-docs/docs/marks/rule/index.html
# Moving relative urls vega-docs/docs/marks/line/index.html
# Moving relative urls vega-docs/docs/marks/text/index.html
# Moving relative urls vega-docs/docs/marks/arc/index.html
# Moving relative urls vega-docs/docs/legends/index.html
# Moving relative urls vega-docs/docs/config/index.html
# Moving relative urls vega-docs/docs/title/index.html
# Moving relative urls vega-docs/docs/triggers/index.html
# Moving relative urls vega-docs/docs/porting-guide/index.html
# Moving relative urls vega-docs/docs/layout/index.html
# Moving relative urls vega-docs/docs/signals/index.html
# Moving relative urls vega-docs/docs/projections/index.html
# Moving relative urls vega-docs/docs/specification/index.html
# Moving relative urls vega-docs/docs/scales/index.html
# Moving relative urls vega-docs/docs/transforms/index.html
# Moving relative urls vega-docs/docs/transforms/tree/index.html
# Moving relative urls vega-docs/docs/transforms/joinaggregate/index.html
# Moving relative urls vega-docs/docs/transforms/geojson/index.html
# Moving relative urls vega-docs/docs/transforms/collect/index.html
# Moving relative urls vega-docs/docs/transforms/pivot/index.html
# Moving relative urls vega-docs/docs/transforms/geoshape/index.html
# Moving relative urls vega-docs/docs/transforms/bin/index.html
# Moving relative urls vega-docs/docs/transforms/linkpath/index.html
# Moving relative urls vega-docs/docs/transforms/quantile/index.html
# Moving relative urls vega-docs/docs/transforms/resolvefilter/index.html
# Moving relative urls vega-docs/docs/transforms/aggregate/index.html
# Moving relative urls vega-docs/docs/transforms/contour/index.html
# Moving relative urls vega-docs/docs/transforms/cross/index.html
# Moving relative urls vega-docs/docs/transforms/geopoint/index.html
# Moving relative urls vega-docs/docs/transforms/pack/index.html
# Moving relative urls vega-docs/docs/transforms/label/index.html
# Moving relative urls vega-docs/docs/transforms/density/index.html
# Moving relative urls vega-docs/docs/transforms/timeunit/index.html
# Moving relative urls vega-docs/docs/transforms/lookup/index.html
# Moving relative urls vega-docs/docs/transforms/impute/index.html
# Moving relative urls vega-docs/docs/transforms/graticule/index.html
# Moving relative urls vega-docs/docs/transforms/countpattern/index.html
# Moving relative urls vega-docs/docs/transforms/pie/index.html
# Moving relative urls vega-docs/docs/transforms/extent/index.html
# Moving relative urls vega-docs/docs/transforms/project/index.html
# Moving relative urls vega-docs/docs/transforms/kde/index.html
# Moving relative urls vega-docs/docs/transforms/kde2d/index.html
# Moving relative urls vega-docs/docs/transforms/voronoi/index.html
# Moving relative urls vega-docs/docs/transforms/dotbin/index.html
# Moving relative urls vega-docs/docs/transforms/flatten/index.html
# Moving relative urls vega-docs/docs/transforms/identifier/index.html
# Moving relative urls vega-docs/docs/transforms/stratify/index.html
# Moving relative urls vega-docs/docs/transforms/treelinks/index.html
# Moving relative urls vega-docs/docs/transforms/window/index.html
# Moving relative urls vega-docs/docs/transforms/loess/index.html
# Moving relative urls vega-docs/docs/transforms/formula/index.html
# Moving relative urls vega-docs/docs/transforms/sample/index.html
# Moving relative urls vega-docs/docs/transforms/crossfilter/index.html
# Moving relative urls vega-docs/docs/transforms/fold/index.html
# Moving relative urls vega-docs/docs/transforms/wordcloud/index.html
# Moving relative urls vega-docs/docs/transforms/heatmap/index.html
# Moving relative urls vega-docs/docs/transforms/geopath/index.html
# Moving relative urls vega-docs/docs/transforms/stack/index.html
# Moving relative urls vega-docs/docs/transforms/filter/index.html
# Moving relative urls vega-docs/docs/transforms/partition/index.html
# Moving relative urls vega-docs/docs/transforms/regression/index.html
# Moving relative urls vega-docs/docs/transforms/sequence/index.html
# Moving relative urls vega-docs/docs/transforms/force/index.html
# Moving relative urls vega-docs/docs/transforms/treemap/index.html
# Moving relative urls vega-docs/docs/transforms/nest/index.html
# Moving relative urls vega-docs/docs/transforms/isocontour/index.html
# Moving relative urls vega-docs/docs/expressions/index.html
# Moving relative urls vega-docs/docs/api/statistics/index.html
# Moving relative urls vega-docs/docs/api/locale/index.html
# Moving relative urls vega-docs/docs/api/util/index.html
# Moving relative urls vega-docs/docs/api/debugging/index.html
# Moving relative urls vega-docs/docs/api/parser/index.html
# Moving relative urls vega-docs/docs/api/time/index.html
# Moving relative urls vega-docs/docs/api/view/index.html
# Moving relative urls vega-docs/docs/api/extensibility/index.html
# Moving relative urls vega-docs/docs/data/index.html
# Moving relative urls vega-docs/examples/index.html
# Moving relative urls vega-docs/examples/arc-diagram/index.html
# Moving relative urls vega-docs/examples/platformer/index.html
# Moving relative urls vega-docs/examples/histogram-null-values/index.html
# Moving relative urls vega-docs/examples/world-map/index.html
# Moving relative urls vega-docs/examples/pacman/index.html
# Moving relative urls vega-docs/examples/falkensee-population/index.html
# Moving relative urls vega-docs/examples/error-bars/index.html
# Moving relative urls vega-docs/examples/overview-plus-detail/index.html
# Moving relative urls vega-docs/examples/edge-bundling/index.html
# Moving relative urls vega-docs/examples/connected-scatter-plot/index.html
# Moving relative urls vega-docs/examples/wheat-and-wages/index.html
# Moving relative urls vega-docs/examples/zoomable-circle-packing/index.html
# Moving relative urls vega-docs/examples/word-cloud/index.html
# Moving relative urls vega-docs/examples/u-district-cuisine/index.html
# Moving relative urls vega-docs/examples/scatter-plot-null-values/index.html
# Moving relative urls vega-docs/examples/zoomable-world-map/index.html
# Moving relative urls vega-docs/examples/annual-precipitation/index.html
# Moving relative urls vega-docs/examples/crossfilter-flights/index.html
# Moving relative urls vega-docs/examples/wheat-plot/index.html
# Moving relative urls vega-docs/examples/violin-plot/index.html
# Moving relative urls vega-docs/examples/flight-passengers/index.html
# Moving relative urls vega-docs/examples/stock-index-chart/index.html
# Moving relative urls vega-docs/examples/circle-packing/index.html
# Moving relative urls vega-docs/examples/reorderable-matrix/index.html
# Moving relative urls vega-docs/examples/pie-chart/index.html
# Moving relative urls vega-docs/examples/top-k-plot/index.html
# Moving relative urls vega-docs/examples/labeled-scatter-plot/index.html
# Moving relative urls vega-docs/examples/stacked-area-chart/index.html
# Moving relative urls vega-docs/examples/bar-chart/index.html
# Moving relative urls vega-docs/examples/population-pyramid/index.html
# Moving relative urls vega-docs/examples/global-development/index.html
# Moving relative urls vega-docs/examples/serpentine-timeline/index.html
# Moving relative urls vega-docs/examples/annual-temperature/index.html
# Moving relative urls vega-docs/examples/projections/index.html
# Moving relative urls vega-docs/examples/top-k-plot-with-others/index.html
# Moving relative urls vega-docs/examples/timelines/index.html
# Moving relative urls vega-docs/examples/quantile-dot-plot/index.html
# Moving relative urls vega-docs/examples/binned-scatter-plot/index.html
# Moving relative urls vega-docs/examples/box-plot/index.html
# Moving relative urls vega-docs/examples/grouped-bar-chart/index.html
# Moving relative urls vega-docs/examples/tree-layout/index.html
# Moving relative urls vega-docs/examples/pi-monte-carlo/index.html
# Moving relative urls vega-docs/examples/time-units/index.html
# Moving relative urls vega-docs/examples/county-unemployment/index.html
# Moving relative urls vega-docs/examples/hypothetical-outcome-plots/index.html
# Moving relative urls vega-docs/examples/radar-chart/index.html
# Moving relative urls vega-docs/examples/parallel-coordinates/index.html
# Moving relative urls vega-docs/examples/barley-trellis-plot/index.html
# Moving relative urls vega-docs/examples/density-heatmaps/index.html
# Moving relative urls vega-docs/examples/stacked-bar-chart/index.html
# Moving relative urls vega-docs/examples/contour-plot/index.html
# Moving relative urls vega-docs/examples/force-directed-layout/index.html
# Moving relative urls vega-docs/examples/quantile-quantile-plot/index.html
# Moving relative urls vega-docs/examples/budget-forecasts/index.html
# Moving relative urls vega-docs/examples/brushing-scatter-plots/index.html
# Moving relative urls vega-docs/examples/area-chart/index.html
# Moving relative urls vega-docs/examples/zoomable-binned-plot/index.html
# Moving relative urls vega-docs/examples/zoomable-scatter-plot/index.html
# Moving relative urls vega-docs/examples/line-chart/index.html
# Moving relative urls vega-docs/examples/distortion-comparison/index.html
# Moving relative urls vega-docs/examples/weekly-temperature/index.html
# Moving relative urls vega-docs/examples/watch/index.html
# Moving relative urls vega-docs/examples/heatmap/index.html
# Moving relative urls vega-docs/examples/dot-plot/index.html
# Moving relative urls vega-docs/examples/probability-density/index.html
# Moving relative urls vega-docs/examples/warming-stripes/index.html
# Moving relative urls vega-docs/examples/horizon-graph/index.html
# Moving relative urls vega-docs/examples/regression/index.html
# Moving relative urls vega-docs/examples/volcano-contours/index.html
# Moving relative urls vega-docs/examples/radial-plot/index.html
# Moving relative urls vega-docs/examples/sunburst/index.html
# Moving relative urls vega-docs/examples/loess-regression/index.html
# Moving relative urls vega-docs/examples/calendar-view/index.html
# Moving relative urls vega-docs/examples/interactive-legend/index.html
# Moving relative urls vega-docs/examples/job-voyager/index.html
# Moving relative urls vega-docs/examples/scatter-plot/index.html
# Moving relative urls vega-docs/examples/beeswarm-plot/index.html
# Moving relative urls vega-docs/examples/treemap/index.html
# Moving relative urls vega-docs/examples/wind-vectors/index.html
# Moving relative urls vega-docs/examples/nested-bar-chart/index.html
# Moving relative urls vega-docs/examples/radial-tree-layout/index.html
# Moving relative urls vega-docs/examples/clock/index.html
# Moving relative urls vega-docs/examples/packed-bubble-chart/index.html
# Moving relative urls vega-docs/examples/earthquakes/index.html
# Moving relative urls vega-docs/examples/histogram/index.html
# Moving relative urls vega-docs/examples/dorling-cartogram/index.html
# Moving relative urls vega-docs/examples/airport-connections/index.html
# Moving relative urls vega-docs/examples/donut-chart/index.html
# Moving relative urls vega-docs/tutorials/index.html
# Moving relative urls vega-docs/tutorials/bar-chart/index.html
# Moving relative urls vega-docs/tutorials/airports/index.html

# %%
# Then get entries to add to the database
def get_soup(filename):
    with open(filename) as fp:
        text = fp.read()
    return BeautifulSoup(text, 'lxml')

# %%
def get_guide_entries():
    tutorial_soup = get_soup("vega-docs/tutorials/index.html")
    tutorial_links = tutorial_soup.find("section", {"class": "page-content"}).findAll(
        "a"
    )

    tutorial_entries = [
        [
            l.getText().strip(),
            "Guide",
            path.join("/tutorials", l["href"], "index.html")
            if "https://" not in l["href"]
            else l["href"],
        ]
        for l in tutorial_links
    ]

    # Hardcoding since there isn't a clean directory menu to all the subpages for this
    # section.
    usage_entries = [
        ['Usage: Main', 'Guide', '/usage/index.html'],
        ['Usage: Internet Explorer', 'Guide', '/usage/internet-explorer/index.html'],
        ['Usage: Interpreter', 'Guide', '/usage/interpreter/index.html'],
        # Also passing in root to API
        # TODO: rewrite all URLs in terms of relative paths
        ['Documentation: Main', 'Guide', '/docs/index.html'],
        # bonuses from API namespace
        ['Debugging', 'Guide', '/docs/api/debugging/index.html'],
        ['Extensibility', 'Guide', '/docs/api/extensibility/index.html']
    ]

    about_soup = get_soup("vega-docs/about/index.html")
    about_links = about_soup.find("ul", {"class": "sidebar-nav"}).findAll(
        "a"
    )

    about_entries = [
        [
            l.getText().strip(),
            "Guide",
            # Need to avoid making relative paths if it's to a direct link
            path.join('/', path.relpath(l["href"], "../"), 'index.html') if not 'https:' in l["href"] else l["href"]
        ]
        for l in about_links
    ]

    return [
        *tutorial_entries,
        *usage_entries,
        *about_entries
        # other special entries 
        # ['Comparison', 'Guide', '/comparison.html'],
        #  ['Overview', 'Guide', '/index.html'],   # not needed, is main page
    ]

# %%
get_guide_entries()
# Out:
# [['Let’s Make a Bar Chart', 'Guide', '/tutorials/bar-chart/index.html'],
#  ['A Guide to Guides: Axes & Legends',
#   'Guide',
#   'https://observablehq.com/@vega/a-guide-to-guides-axes-legends-in-vega'],
#  ['Mapping Airport Connections', 'Guide', '/tutorials/airports/index.html'],
#  ['How Vega Works', 'Guide', 'https://observablehq.com/@vega/how-vega-works'],
#  ['Usage: Main', 'Guide', '/usage/index.html'],
#  ['Usage: Internet Explorer', 'Guide', '/usage/internet-explorer/index.html'],
#  ['Usage: Interpreter', 'Guide', '/usage/interpreter/index.html'],
#  ['Documentation: Main', 'Guide', '/docs/index.html'],
#  ['Debugging', 'Guide', '/docs/api/debugging/index.html'],
#  ['Extensibility', 'Guide', '/docs/api/extensibility/index.html'],
#  ['About', 'Guide', '/about/index.html'],
#  ['Video', 'Guide', '/about/video/index.html'],
#  ['Projects', 'Guide', '/about/projects/index.html'],
#  ['Research', 'Guide', '/about/research/index.html'],
#  ['Vega and D3', 'Guide', '/about/vega-and-d3/index.html'],
#  ['Code of Conduct',
#   'Guide',
#   'https://github.com/vega/.github/blob/master/CODE_OF_CONDUCT.md']]

# %%
#get_sample_entries()

# %%
def get_sample_entries():
    examples_soup = get_soup('vega-docs/examples/index.html')
    links = examples_soup.find('section', {"class": "page-content"}).findAll('a')
    
    entries = [
        [f"{l.getText().strip()}",
        'Sample',
        os.path.join('/examples/', l['href'], 'index.html')]
        for l in links  
    ]
    
    return entries

# %% [markdown]
# Notes on docs
#
# - API has 1 level of nesting per page
# - Spec has 1 level of nesting for most, except for Mark and Transforms

# %%
#get_structures_entries()

# %%
# Process the "docs" part of the site directory
def get_structures_entries():

    docs_soup = get_soup('vega-docs/docs/index.html')

    spec_table = docs_soup.find('h2', {"id": 'specification-reference'}).findNext('table')
    cat_links = spec_table.findAll('a') 
    cat_entries = [
        [f"{l.getText().strip()}",
        'Category',
        path.join('/docs', l['href'], 'index.html')
        ]
        for l in cat_links  
    ]

    # next, we process the JS API
    # Strictly speaking Debugging should be a guide.
    api_table = docs_soup.find('h2', {"id": 'vega-api-reference'}).findNext('table')
    api_links = api_table.findAll('a') 
    ignoreModules = ['Debugging', 'Extensibility'] # not vega packages, belong in guide
    module_entries = [
        [f"{l.getText().strip()}",
        'Module',
        path.join('/docs',l['href'], 'index.html')
        ]
        # this code is quite scrappy but OK for now
        for l in api_links if not any(word in l.getText() for word in ignoreModules) 
    ]

    
    #  Lets get the marks
    marks_soup = get_soup("vega-docs/docs/marks/index.html")
    marks_nav = marks_soup.find('aside').find('ul', {"class": 'sub-menu-nav'})
    marks_links = marks_nav.findAll('a')
    marks_entries = [
        [f"mark.{l.getText().strip()}",
        'Interface',
        path.join('/', path.relpath(l['href'], '../../'), 'index.html')
        ]
        for l in marks_links
    ]

    # close with the transforms
    transforms_soup = get_soup("vega-docs/docs/transforms/index.html")
    transforms_nav = transforms_soup.find('aside').find('ul', {"class": 'sub-menu-nav'})
    transforms_links = transforms_nav.findAll('a')
    transforms_entries = [
        [f"transform.{l.getText().strip()}",
        'Interface',
        path.join('/', path.relpath(l['href'], '../../'), 'index.html')
        ]
        for l in transforms_links
    ]

            
    return [
        *cat_entries,
        *module_entries,
        *marks_entries,
        *transforms_entries,
    ]

# %%
all_entries = [*get_guide_entries(), *get_sample_entries(), *get_structures_entries()]

# %%
# Add 1 row
def addRow(cursor, name, rowType, path):
    statement = f"INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('{name}', '{rowType}', '{path}');"
    if DEBUG:
        print(statement)
    cursor.execute(statement)

# %%
try:
    # TODO: evaluate if this needs to become idempotent
    connection = sqlite3.connect(SQLITE_PATH)
    cursor = connection.cursor()
    
    # Uncomment these on first run
    cursor.execute('CREATE TABLE searchIndex(id INTEGER PRIMARY KEY, name TEXT, type TEXT, path TEXT);')
    cursor.execute('CREATE UNIQUE INDEX anchor ON searchIndex (name, type, path);')

    # Debug row
    #     addRow(cursor, 'Getting Started' ,'Guide', '/tutorials/getting_started.html#tutorial-overview')
    for entry in all_entries:
        addRow(cursor, *entry)
    
    connection.commit()
    
except sqlite3.Error as error:
    print("Error while executing sqlite script", error)
    
finally:
    if connection:
        connection.close()
        print('connection closed')
# Out:
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Let’s Make a Bar Chart', 'Guide', '/tutorials/bar-chart/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('A Guide to Guides: Axes & Legends', 'Guide', 'https://observablehq.com/@vega/a-guide-to-guides-axes-legends-in-vega');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Mapping Airport Connections', 'Guide', '/tutorials/airports/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('How Vega Works', 'Guide', 'https://observablehq.com/@vega/how-vega-works');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Usage: Main', 'Guide', '/usage/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Usage: Internet Explorer', 'Guide', '/usage/internet-explorer/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Usage: Interpreter', 'Guide', '/usage/interpreter/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Documentation: Main', 'Guide', '/docs/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Debugging', 'Guide', '/docs/api/debugging/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Extensibility', 'Guide', '/docs/api/extensibility/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('About', 'Guide', '/about/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Video', 'Guide', '/about/video/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Projects', 'Guide', '/about/projects/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Research', 'Guide', '/about/research/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Vega and D3', 'Guide', '/about/vega-and-d3/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Code of Conduct', 'Guide', 'https://github.com/vega/.github/blob/master/CODE_OF_CONDUCT.md');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Bar Chart', 'Sample', '/examples/bar-chart/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Stacked Bar Chart', 'Sample', '/examples/stacked-bar-chart/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Grouped Bar Chart', 'Sample', '/examples/grouped-bar-chart/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Nested Bar Chart', 'Sample', '/examples/nested-bar-chart/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Population Pyramid', 'Sample', '/examples/population-pyramid/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Line Chart', 'Sample', '/examples/line-chart/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Area Chart', 'Sample', '/examples/area-chart/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Stacked Area Chart', 'Sample', '/examples/stacked-area-chart/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Horizon Graph', 'Sample', '/examples/horizon-graph/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Job Voyager', 'Sample', '/examples/job-voyager/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Pie Chart', 'Sample', '/examples/pie-chart/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Donut Chart', 'Sample', '/examples/donut-chart/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Radial Plot', 'Sample', '/examples/radial-plot/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Radar Chart', 'Sample', '/examples/radar-chart/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Scatter Plot', 'Sample', '/examples/scatter-plot/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Scatter Plot Null Values', 'Sample', '/examples/scatter-plot-null-values/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Connected Scatter Plot', 'Sample', '/examples/connected-scatter-plot/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Error Bars', 'Sample', '/examples/error-bars/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Barley Trellis Plot', 'Sample', '/examples/barley-trellis-plot/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Regression', 'Sample', '/examples/regression/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Loess Regression', 'Sample', '/examples/loess-regression/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Labeled Scatter Plot', 'Sample', '/examples/labeled-scatter-plot/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Top K Plot', 'Sample', '/examples/top-k-plot/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Top K Plot With Others', 'Sample', '/examples/top-k-plot-with-others/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Histogram', 'Sample', '/examples/histogram/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Histogram Null Values', 'Sample', '/examples/histogram-null-values/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Dot Plot', 'Sample', '/examples/dot-plot/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Probability Density', 'Sample', '/examples/probability-density/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Box Plot', 'Sample', '/examples/box-plot/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Violin Plot', 'Sample', '/examples/violin-plot/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Binned Scatter Plot', 'Sample', '/examples/binned-scatter-plot/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Contour Plot', 'Sample', '/examples/contour-plot/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Wheat Plot', 'Sample', '/examples/wheat-plot/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Quantile Quantile Plot', 'Sample', '/examples/quantile-quantile-plot/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Quantile Dot Plot', 'Sample', '/examples/quantile-dot-plot/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Hypothetical Outcome Plots', 'Sample', '/examples/hypothetical-outcome-plots/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Time Units', 'Sample', '/examples/time-units/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('County Unemployment', 'Sample', '/examples/county-unemployment/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Dorling Cartogram', 'Sample', '/examples/dorling-cartogram/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('World Map', 'Sample', '/examples/world-map/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Earthquakes', 'Sample', '/examples/earthquakes/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Projections', 'Sample', '/examples/projections/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Zoomable World Map', 'Sample', '/examples/zoomable-world-map/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Distortion Comparison', 'Sample', '/examples/distortion-comparison/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Volcano Contours', 'Sample', '/examples/volcano-contours/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Wind Vectors', 'Sample', '/examples/wind-vectors/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Annual Precipitation', 'Sample', '/examples/annual-precipitation/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Tree Layout', 'Sample', '/examples/tree-layout/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Radial Tree Layout', 'Sample', '/examples/radial-tree-layout/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Treemap', 'Sample', '/examples/treemap/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Circle Packing', 'Sample', '/examples/circle-packing/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Sunburst', 'Sample', '/examples/sunburst/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Edge Bundling', 'Sample', '/examples/edge-bundling/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Force Directed Layout', 'Sample', '/examples/force-directed-layout/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Reorderable Matrix', 'Sample', '/examples/reorderable-matrix/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Arc Diagram', 'Sample', '/examples/arc-diagram/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Airport Connections', 'Sample', '/examples/airport-connections/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Heatmap', 'Sample', '/examples/heatmap/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Density Heatmaps', 'Sample', '/examples/density-heatmaps/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Parallel Coordinates', 'Sample', '/examples/parallel-coordinates/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Word Cloud', 'Sample', '/examples/word-cloud/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Beeswarm Plot', 'Sample', '/examples/beeswarm-plot/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Calendar View', 'Sample', '/examples/calendar-view/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Packed Bubble Chart', 'Sample', '/examples/packed-bubble-chart/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Budget Forecasts', 'Sample', '/examples/budget-forecasts/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Wheat And Wages', 'Sample', '/examples/wheat-and-wages/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Falkensee Population', 'Sample', '/examples/falkensee-population/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Annual Temperature', 'Sample', '/examples/annual-temperature/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Weekly Temperature', 'Sample', '/examples/weekly-temperature/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Flight Passengers', 'Sample', '/examples/flight-passengers/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Timelines', 'Sample', '/examples/timelines/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('U District Cuisine', 'Sample', '/examples/u-district-cuisine/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Clock', 'Sample', '/examples/clock/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Watch', 'Sample', '/examples/watch/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Warming Stripes', 'Sample', '/examples/warming-stripes/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Serpentine Timeline', 'Sample', '/examples/serpentine-timeline/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Crossfilter Flights', 'Sample', '/examples/crossfilter-flights/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Overview Plus Detail', 'Sample', '/examples/overview-plus-detail/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Brushing Scatter Plots', 'Sample', '/examples/brushing-scatter-plots/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Zoomable Scatter Plot', 'Sample', '/examples/zoomable-scatter-plot/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Zoomable Binned Plot', 'Sample', '/examples/zoomable-binned-plot/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Global Development', 'Sample', '/examples/global-development/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Interactive Legend', 'Sample', '/examples/interactive-legend/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Stock Index Chart', 'Sample', '/examples/stock-index-chart/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Pi Monte Carlo', 'Sample', '/examples/pi-monte-carlo/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Zoomable Circle Packing', 'Sample', '/examples/zoomable-circle-packing/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Pacman', 'Sample', '/examples/pacman/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Platformer', 'Sample', '/examples/platformer/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Specification', 'Category', '/docs/specification/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Config', 'Category', '/docs/config/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Data', 'Category', '/docs/data/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Transforms', 'Category', '/docs/transforms/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Triggers', 'Category', '/docs/triggers/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Projections', 'Category', '/docs/projections/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Scales', 'Category', '/docs/scales/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Schemes', 'Category', '/docs/schemes/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Axes', 'Category', '/docs/axes/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Legends', 'Category', '/docs/legends/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Title', 'Category', '/docs/title/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Marks', 'Category', '/docs/marks/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Signals', 'Category', '/docs/signals/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Event Streams', 'Category', '/docs/event-streams/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Expressions', 'Category', '/docs/expressions/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Layout', 'Category', '/docs/layout/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Types', 'Category', '/docs/types/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Parser', 'Module', '/docs/api/parser/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('View', 'Module', '/docs/api/view/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Locale', 'Module', '/docs/api/locale/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Statistics', 'Module', '/docs/api/statistics/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Time', 'Module', '/docs/api/time/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('Util', 'Module', '/docs/api/util/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('mark.arc', 'Interface', '/docs/marks/arc/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('mark.area', 'Interface', '/docs/marks/area/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('mark.group', 'Interface', '/docs/marks/group/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('mark.image', 'Interface', '/docs/marks/image/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('mark.line', 'Interface', '/docs/marks/line/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('mark.path', 'Interface', '/docs/marks/path/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('mark.rect', 'Interface', '/docs/marks/rect/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('mark.rule', 'Interface', '/docs/marks/rule/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('mark.shape', 'Interface', '/docs/marks/shape/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('mark.symbol', 'Interface', '/docs/marks/symbol/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('mark.text', 'Interface', '/docs/marks/text/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('mark.trail', 'Interface', '/docs/marks/trail/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.aggregate', 'Interface', '/docs/transforms/aggregate/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.bin', 'Interface', '/docs/transforms/bin/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.collect', 'Interface', '/docs/transforms/collect/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.countpattern', 'Interface', '/docs/transforms/countpattern/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.contour', 'Interface', '/docs/transforms/contour/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.cross', 'Interface', '/docs/transforms/cross/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.crossfilter', 'Interface', '/docs/transforms/crossfilter/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.density', 'Interface', '/docs/transforms/density/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.dotbin', 'Interface', '/docs/transforms/dotbin/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.extent', 'Interface', '/docs/transforms/extent/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.filter', 'Interface', '/docs/transforms/filter/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.flatten', 'Interface', '/docs/transforms/flatten/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.fold', 'Interface', '/docs/transforms/fold/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.force', 'Interface', '/docs/transforms/force/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.formula', 'Interface', '/docs/transforms/formula/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.geojson', 'Interface', '/docs/transforms/geojson/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.geopath', 'Interface', '/docs/transforms/geopath/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.geopoint', 'Interface', '/docs/transforms/geopoint/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.geoshape', 'Interface', '/docs/transforms/geoshape/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.graticule', 'Interface', '/docs/transforms/graticule/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.heatmap', 'Interface', '/docs/transforms/heatmap/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.identifier', 'Interface', '/docs/transforms/identifier/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.impute', 'Interface', '/docs/transforms/impute/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.isocontour', 'Interface', '/docs/transforms/isocontour/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.joinaggregate', 'Interface', '/docs/transforms/joinaggregate/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.kde', 'Interface', '/docs/transforms/kde/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.kde2d', 'Interface', '/docs/transforms/kde2d/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.label', 'Interface', '/docs/transforms/label/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.linkpath', 'Interface', '/docs/transforms/linkpath/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.loess', 'Interface', '/docs/transforms/loess/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.lookup', 'Interface', '/docs/transforms/lookup/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.nest', 'Interface', '/docs/transforms/nest/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.pack', 'Interface', '/docs/transforms/pack/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.partition', 'Interface', '/docs/transforms/partition/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.pie', 'Interface', '/docs/transforms/pie/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.pivot', 'Interface', '/docs/transforms/pivot/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.project', 'Interface', '/docs/transforms/project/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.quantile', 'Interface', '/docs/transforms/quantile/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.regression', 'Interface', '/docs/transforms/regression/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.resolvefilter', 'Interface', '/docs/transforms/resolvefilter/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.sample', 'Interface', '/docs/transforms/sample/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.sequence', 'Interface', '/docs/transforms/sequence/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.stack', 'Interface', '/docs/transforms/stack/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.stratify', 'Interface', '/docs/transforms/stratify/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.timeunit', 'Interface', '/docs/transforms/timeunit/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.tree', 'Interface', '/docs/transforms/tree/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.treelinks', 'Interface', '/docs/transforms/treelinks/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.treemap', 'Interface', '/docs/transforms/treemap/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.voronoi', 'Interface', '/docs/transforms/voronoi/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.window', 'Interface', '/docs/transforms/window/index.html');
# INSERT OR IGNORE INTO searchIndex(name, type, path) VALUES ('transform.wordcloud', 'Interface', '/docs/transforms/wordcloud/index.html');
# connection closed

# %%
# logos from https://github.com/vega/logos
#!curl https://github.com/vega/logos/blob/master/assets/VG_Color%40128.png  
# !cp img/* $VEGA_DOCSET/

# %%
def enrich_table_of_contents(filename):
    with open(filename) as fp:
        text = fp.read()

    # get the soup
    soup = BeautifulSoup(text, "lxml")
    content = soup.find("section", {"class": "page-content"}) or soup.find(
        "div", {"class": "page-content"}
    )

    if content is None:
        return text

    category_anchors = content.findAll("h2")
    for anchor in category_anchors:
        # ok to have double links
        # if anchor.find("a"):
        #     continue
        # safe quote to handle / path characters
        # https://stackoverflow.com/questions/1695183/how-to-percent-encode-url-parameters-in-python
        safeName = quote(anchor.getText().strip(), safe="")
        dashAnchor = soup.new_tag("a")
        dashAnchor["name"] = f"//apple_ref/cpp/Category/{safeName}"
        dashAnchor["class"] = "dashAnchor"
        anchor.append(dashAnchor)

    section_anchors = content.findAll("h3")
    for anchor in section_anchors:

        if anchor.find("a"):
            continue

        safeName = quote(anchor.getText().strip(), safe="")
        if safeName == "Usage":
            continue # notice this can get spammy, like in config

        dashAnchor = soup.new_tag("a")
        dashAnchor["name"] = f"//apple_ref/cpp/Section/{safeName}"
        dashAnchor["class"] = "dashAnchor"
        anchor.append(dashAnchor)

    function_anchors = content.findAll("a", text="#")
    for anchor in function_anchors:
        safeName = quote(anchor["name"].strip(), safe="")
        # bad for dom to have extra tag, but its ok for us in this case so that in-page links
        # still work with the name reference.
        dashAnchor = soup.new_tag("a")
        dashAnchor["name"] = f"//apple_ref/cpp/Section/{safeName}"
        dashAnchor["class"] = "dashAnchor"

        anchor.append(dashAnchor)

    print(
        "Added",
        len(section_anchors),
        "sections",
        len(category_anchors),
        "functions",
        len(function_anchors),
    )

    return str(soup)

# %%
def remove_page_elements(filename):
    with open(filename) as fp:
        text = fp.read()

    # remove sidebar nav elements
    soup = BeautifulSoup(text, 'lxml')
    sidebar = soup.find('aside', {"class": "page-sidebar"})
    
    if sidebar:
        print("removing sidebar from ", filename)
        sidebar.decompose()
    
    return str(soup)

# %%
# Add "toc" entries for each page.
matches = glob.glob(f"vega-docs/**/*.html", recursive=True)
print(len(matches))

for name in matches:
    if DEBUG:
        print('Enrich table of contents', name)
    processed = enrich_table_of_contents(name)
    
    with open(name, 'w') as fp:
        fp.write(processed)
# Out:
# 192
# Enrich table of contents vega-docs/index.html
# Added 0 sections 0 functions 0
# Enrich table of contents vega-docs/usage/index.html
# Added 7 sections 4 functions 0
# Enrich table of contents vega-docs/usage/interpreter/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/usage/internet-explorer/index.html
# Added 0 sections 2 functions 0
# Enrich table of contents vega-docs/about/index.html
# Added 0 sections 1 functions 0
# Enrich table of contents vega-docs/about/research/index.html
# Added 0 sections 3 functions 0
# Enrich table of contents vega-docs/about/video/index.html
# Added 5 sections 0 functions 0
# Enrich table of contents vega-docs/about/projects/index.html
# Added 0 sections 0 functions 0
# Enrich table of contents vega-docs/about/vega-and-d3/index.html
# Added 0 sections 0 functions 0
# Enrich table of contents vega-docs/about/code-of-conduct/index.html
# Added 0 sections 0 functions 0
# Enrich table of contents vega-docs/docs/index.html
# Added 0 sections 2 functions 0
# Enrich table of contents vega-docs/docs/schemes/index.html
# Added 5 sections 3 functions 67
# Enrich table of contents vega-docs/docs/event-streams/index.html
# /var/folders/rw/wjb8b8ws1td2934nl9bk7_tm0000gp/T/ipykernel_13044/3527363842.py:42: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   function_anchors = content.findAll("a", text="#")
# Added 5 sections 5 functions 0
# Enrich table of contents vega-docs/docs/types/index.html
# Added 0 sections 3 functions 23
# Enrich table of contents vega-docs/docs/axes/index.html
# Added 2 sections 3 functions 0
# Enrich table of contents vega-docs/docs/marks/index.html
# Added 3 sections 8 functions 0
# Enrich table of contents vega-docs/docs/marks/shape/index.html
# Added 1 sections 2 functions 0
# Enrich table of contents vega-docs/docs/marks/rect/index.html
# Added 1 sections 3 functions 0
# Enrich table of contents vega-docs/docs/marks/trail/index.html
# Added 3 sections 1 functions 0
# Enrich table of contents vega-docs/docs/marks/area/index.html
# Added 1 sections 3 functions 0
# Enrich table of contents vega-docs/docs/marks/group/index.html
# Added 1 sections 3 functions 0
# Enrich table of contents vega-docs/docs/marks/path/index.html
# Added 1 sections 3 functions 0
# Enrich table of contents vega-docs/docs/marks/symbol/index.html
# Added 1 sections 3 functions 0
# Enrich table of contents vega-docs/docs/marks/image/index.html
# Added 1 sections 3 functions 0
# Enrich table of contents vega-docs/docs/marks/rule/index.html
# Added 1 sections 2 functions 0
# Enrich table of contents vega-docs/docs/marks/line/index.html
# Added 1 sections 3 functions 0
# Enrich table of contents vega-docs/docs/marks/text/index.html
# Added 1 sections 3 functions 0
# Enrich table of contents vega-docs/docs/marks/arc/index.html
# Added 1 sections 3 functions 0
# Enrich table of contents vega-docs/docs/legends/index.html
# Added 2 sections 3 functions 0
# Enrich table of contents vega-docs/docs/config/index.html
# Added 13 sections 11 functions 0
# Enrich table of contents vega-docs/docs/title/index.html
# Added 2 sections 2 functions 0
# Enrich table of contents vega-docs/docs/triggers/index.html
# Added 0 sections 2 functions 0
# Enrich table of contents vega-docs/docs/porting-guide/index.html
# Added 0 sections 10 functions 0
# Enrich table of contents vega-docs/docs/layout/index.html
# Added 0 sections 1 functions 0
# Enrich table of contents vega-docs/docs/signals/index.html
# Added 7 sections 3 functions 0
# Enrich table of contents vega-docs/docs/projections/index.html
# Added 0 sections 4 functions 0
# Enrich table of contents vega-docs/docs/specification/index.html
# Added 0 sections 3 functions 0
# Enrich table of contents vega-docs/docs/scales/index.html
# Added 18 sections 9 functions 0
# Enrich table of contents vega-docs/docs/transforms/index.html
# Added 0 sections 6 functions 0
# Enrich table of contents vega-docs/docs/transforms/tree/index.html
# Added 0 sections 3 functions 0
# Enrich table of contents vega-docs/docs/transforms/joinaggregate/index.html
# Added 0 sections 3 functions 0
# Enrich table of contents vega-docs/docs/transforms/geojson/index.html
# Added 0 sections 2 functions 0
# Enrich table of contents vega-docs/docs/transforms/collect/index.html
# Added 2 sections 2 functions 0
# Enrich table of contents vega-docs/docs/transforms/pivot/index.html
# Added 0 sections 3 functions 0
# Enrich table of contents vega-docs/docs/transforms/geoshape/index.html
# Added 0 sections 3 functions 0
# Enrich table of contents vega-docs/docs/transforms/bin/index.html
# Added 0 sections 2 functions 0
# Enrich table of contents vega-docs/docs/transforms/linkpath/index.html
# Added 0 sections 3 functions 0
# Enrich table of contents vega-docs/docs/transforms/quantile/index.html
# Added 0 sections 2 functions 0
# Enrich table of contents vega-docs/docs/transforms/resolvefilter/index.html
# Added 0 sections 2 functions 0
# Enrich table of contents vega-docs/docs/transforms/aggregate/index.html
# Added 0 sections 5 functions 0
# Enrich table of contents vega-docs/docs/transforms/contour/index.html
# Added 0 sections 2 functions 0
# Enrich table of contents vega-docs/docs/transforms/cross/index.html
# Added 0 sections 2 functions 0
# Enrich table of contents vega-docs/docs/transforms/geopoint/index.html
# Added 0 sections 3 functions 0
# Enrich table of contents vega-docs/docs/transforms/pack/index.html
# Added 0 sections 3 functions 0
# Enrich table of contents vega-docs/docs/transforms/label/index.html
# Added 0 sections 2 functions 0
# Enrich table of contents vega-docs/docs/transforms/density/index.html
# Added 0 sections 3 functions 4
# Enrich table of contents vega-docs/docs/transforms/timeunit/index.html
# Added 2 sections 3 functions 0
# Enrich table of contents vega-docs/docs/transforms/lookup/index.html
# Added 0 sections 2 functions 0
# Enrich table of contents vega-docs/docs/transforms/impute/index.html
# Added 0 sections 2 functions 0
# Enrich table of contents vega-docs/docs/transforms/graticule/index.html
# Added 0 sections 3 functions 0
# Enrich table of contents vega-docs/docs/transforms/countpattern/index.html
# Added 0 sections 2 functions 0
# Enrich table of contents vega-docs/docs/transforms/pie/index.html
# Added 0 sections 3 functions 0
# Enrich table of contents vega-docs/docs/transforms/extent/index.html
# Added 0 sections 2 functions 0
# Enrich table of contents vega-docs/docs/transforms/project/index.html
# Added 0 sections 2 functions 0
# Enrich table of contents vega-docs/docs/transforms/kde/index.html
# Added 0 sections 2 functions 0
# Enrich table of contents vega-docs/docs/transforms/kde2d/index.html
# Added 0 sections 2 functions 0
# Enrich table of contents vega-docs/docs/transforms/voronoi/index.html
# Added 0 sections 3 functions 0
# Enrich table of contents vega-docs/docs/transforms/dotbin/index.html
# Added 0 sections 2 functions 0
# Enrich table of contents vega-docs/docs/transforms/flatten/index.html
# Added 3 sections 2 functions 0
# Enrich table of contents vega-docs/docs/transforms/identifier/index.html
# Added 0 sections 2 functions 0
# Enrich table of contents vega-docs/docs/transforms/stratify/index.html
# Added 0 sections 2 functions 0
# Enrich table of contents vega-docs/docs/transforms/treelinks/index.html
# Added 0 sections 2 functions 0
# Enrich table of contents vega-docs/docs/transforms/window/index.html
# Added 1 sections 4 functions 0
# Enrich table of contents vega-docs/docs/transforms/loess/index.html
# Added 0 sections 2 functions 0
# Enrich table of contents vega-docs/docs/transforms/formula/index.html
# Added 0 sections 2 functions 0
# Enrich table of contents vega-docs/docs/transforms/sample/index.html
# Added 0 sections 2 functions 0
# Enrich table of contents vega-docs/docs/transforms/crossfilter/index.html
# Added 0 sections 2 functions 0
# Enrich table of contents vega-docs/docs/transforms/fold/index.html
# Added 0 sections 2 functions 0
# Enrich table of contents vega-docs/docs/transforms/wordcloud/index.html
# Added 0 sections 3 functions 0
# Enrich table of contents vega-docs/docs/transforms/heatmap/index.html
# Added 2 sections 2 functions 0
# Enrich table of contents vega-docs/docs/transforms/geopath/index.html
# Added 0 sections 3 functions 0
# Enrich table of contents vega-docs/docs/transforms/stack/index.html
# Added 0 sections 3 functions 0
# Enrich table of contents vega-docs/docs/transforms/filter/index.html
# Added 0 sections 2 functions 0
# Enrich table of contents vega-docs/docs/transforms/partition/index.html
# Added 0 sections 3 functions 0
# Enrich table of contents vega-docs/docs/transforms/regression/index.html
# Added 2 sections 2 functions 0
# Enrich table of contents vega-docs/docs/transforms/sequence/index.html
# Added 0 sections 2 functions 0
# Enrich table of contents vega-docs/docs/transforms/force/index.html
# Added 0 sections 4 functions 6
# Enrich table of contents vega-docs/docs/transforms/treemap/index.html
# Added 0 sections 3 functions 0
# Enrich table of contents vega-docs/docs/transforms/nest/index.html
# Added 0 sections 3 functions 0
# Enrich table of contents vega-docs/docs/transforms/isocontour/index.html
# Added 0 sections 2 functions 0
# Enrich table of contents vega-docs/docs/expressions/index.html
# Added 0 sections 22 functions 178
# Enrich table of contents vega-docs/docs/api/statistics/index.html
# Added 1 sections 5 functions 35
# Enrich table of contents vega-docs/docs/api/locale/index.html
# Added 0 sections 2 functions 5
# Enrich table of contents vega-docs/docs/api/util/index.html
# Added 0 sections 10 functions 69
# Enrich table of contents vega-docs/docs/api/debugging/index.html
# Added 0 sections 7 functions 0
# Enrich table of contents vega-docs/docs/api/parser/index.html
# Added 0 sections 1 functions 1
# Enrich table of contents vega-docs/docs/api/time/index.html
# Added 1 sections 3 functions 16
# Enrich table of contents vega-docs/docs/api/view/index.html
# Added 0 sections 8 functions 44
# Enrich table of contents vega-docs/docs/api/extensibility/index.html
# Added 0 sections 7 functions 6
# Enrich table of contents vega-docs/docs/data/index.html
# Added 6 sections 4 functions 0
# Enrich table of contents vega-docs/examples/index.html
# Added 0 sections 11 functions 0
# Enrich table of contents vega-docs/examples/arc-diagram/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/platformer/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/histogram-null-values/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/world-map/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/pacman/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/falkensee-population/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/error-bars/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/overview-plus-detail/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/edge-bundling/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/connected-scatter-plot/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/wheat-and-wages/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/zoomable-circle-packing/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/word-cloud/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/u-district-cuisine/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/scatter-plot-null-values/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/zoomable-world-map/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/annual-precipitation/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/crossfilter-flights/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/wheat-plot/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/violin-plot/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/flight-passengers/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/stock-index-chart/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/circle-packing/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/reorderable-matrix/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/pie-chart/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/top-k-plot/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/labeled-scatter-plot/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/stacked-area-chart/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/bar-chart/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/population-pyramid/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/global-development/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/serpentine-timeline/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/annual-temperature/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/projections/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/top-k-plot-with-others/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/timelines/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/quantile-dot-plot/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/binned-scatter-plot/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/box-plot/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/grouped-bar-chart/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/tree-layout/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/pi-monte-carlo/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/time-units/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/county-unemployment/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/hypothetical-outcome-plots/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/radar-chart/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/parallel-coordinates/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/barley-trellis-plot/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/density-heatmaps/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/stacked-bar-chart/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/contour-plot/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/force-directed-layout/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/quantile-quantile-plot/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/budget-forecasts/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/brushing-scatter-plots/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/area-chart/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/zoomable-binned-plot/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/zoomable-scatter-plot/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/line-chart/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/distortion-comparison/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/weekly-temperature/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/watch/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/heatmap/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/dot-plot/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/probability-density/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/warming-stripes/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/horizon-graph/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/regression/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/volcano-contours/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/radial-plot/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/sunburst/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/loess-regression/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/calendar-view/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/interactive-legend/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/job-voyager/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/scatter-plot/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/beeswarm-plot/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/treemap/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/wind-vectors/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/nested-bar-chart/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/radial-tree-layout/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/clock/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/packed-bubble-chart/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/earthquakes/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/histogram/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/dorling-cartogram/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/airport-connections/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/examples/donut-chart/index.html
# Added 1 sections 0 functions 0
# Enrich table of contents vega-docs/tutorials/index.html
# Added 4 sections 0 functions 0
# Enrich table of contents vega-docs/tutorials/bar-chart/index.html
# Added 0 sections 7 functions 0
# Enrich table of contents vega-docs/tutorials/airports/index.html
# Added 3 sections 12 functions 0

# %%
matches = glob.glob(f"vega-docs/**/*.html", recursive=True)
if DEBUG:
    print('Files', len(matches))
for name in matches:    
    # https://stackoverflow.com/questions/5598524/can-i-remove-script-tags-with-beautifulsoup
    processed = remove_page_elements(name)
    
    with open(name, 'w') as fp:
        fp.write(processed)
# Out:
# Files 192
# removing sidebar from  vega-docs/about/index.html
# removing sidebar from  vega-docs/about/research/index.html
# removing sidebar from  vega-docs/about/video/index.html
# removing sidebar from  vega-docs/about/projects/index.html
# removing sidebar from  vega-docs/about/vega-and-d3/index.html
# removing sidebar from  vega-docs/about/code-of-conduct/index.html
# removing sidebar from  vega-docs/docs/schemes/index.html
# removing sidebar from  vega-docs/docs/event-streams/index.html
# removing sidebar from  vega-docs/docs/types/index.html
# removing sidebar from  vega-docs/docs/axes/index.html
# removing sidebar from  vega-docs/docs/marks/index.html
# removing sidebar from  vega-docs/docs/marks/shape/index.html
# removing sidebar from  vega-docs/docs/marks/rect/index.html
# removing sidebar from  vega-docs/docs/marks/trail/index.html
# removing sidebar from  vega-docs/docs/marks/area/index.html
# removing sidebar from  vega-docs/docs/marks/group/index.html
# removing sidebar from  vega-docs/docs/marks/path/index.html
# removing sidebar from  vega-docs/docs/marks/symbol/index.html
# removing sidebar from  vega-docs/docs/marks/image/index.html
# removing sidebar from  vega-docs/docs/marks/rule/index.html
# removing sidebar from  vega-docs/docs/marks/line/index.html
# removing sidebar from  vega-docs/docs/marks/text/index.html
# removing sidebar from  vega-docs/docs/marks/arc/index.html
# removing sidebar from  vega-docs/docs/legends/index.html
# removing sidebar from  vega-docs/docs/config/index.html
# removing sidebar from  vega-docs/docs/title/index.html
# removing sidebar from  vega-docs/docs/triggers/index.html
# removing sidebar from  vega-docs/docs/layout/index.html
# removing sidebar from  vega-docs/docs/signals/index.html
# removing sidebar from  vega-docs/docs/projections/index.html
# removing sidebar from  vega-docs/docs/specification/index.html
# removing sidebar from  vega-docs/docs/scales/index.html
# removing sidebar from  vega-docs/docs/transforms/index.html
# removing sidebar from  vega-docs/docs/transforms/tree/index.html
# removing sidebar from  vega-docs/docs/transforms/joinaggregate/index.html
# removing sidebar from  vega-docs/docs/transforms/geojson/index.html
# removing sidebar from  vega-docs/docs/transforms/collect/index.html
# removing sidebar from  vega-docs/docs/transforms/pivot/index.html
# removing sidebar from  vega-docs/docs/transforms/geoshape/index.html
# removing sidebar from  vega-docs/docs/transforms/bin/index.html
# removing sidebar from  vega-docs/docs/transforms/linkpath/index.html
# removing sidebar from  vega-docs/docs/transforms/quantile/index.html
# removing sidebar from  vega-docs/docs/transforms/resolvefilter/index.html
# removing sidebar from  vega-docs/docs/transforms/aggregate/index.html
# removing sidebar from  vega-docs/docs/transforms/contour/index.html
# removing sidebar from  vega-docs/docs/transforms/cross/index.html
# removing sidebar from  vega-docs/docs/transforms/geopoint/index.html
# removing sidebar from  vega-docs/docs/transforms/pack/index.html
# removing sidebar from  vega-docs/docs/transforms/label/index.html
# removing sidebar from  vega-docs/docs/transforms/density/index.html
# removing sidebar from  vega-docs/docs/transforms/timeunit/index.html
# removing sidebar from  vega-docs/docs/transforms/lookup/index.html
# removing sidebar from  vega-docs/docs/transforms/impute/index.html
# removing sidebar from  vega-docs/docs/transforms/graticule/index.html
# removing sidebar from  vega-docs/docs/transforms/countpattern/index.html
# removing sidebar from  vega-docs/docs/transforms/pie/index.html
# removing sidebar from  vega-docs/docs/transforms/extent/index.html
# removing sidebar from  vega-docs/docs/transforms/project/index.html
# removing sidebar from  vega-docs/docs/transforms/kde/index.html
# removing sidebar from  vega-docs/docs/transforms/kde2d/index.html
# removing sidebar from  vega-docs/docs/transforms/voronoi/index.html
# removing sidebar from  vega-docs/docs/transforms/dotbin/index.html
# removing sidebar from  vega-docs/docs/transforms/flatten/index.html
# removing sidebar from  vega-docs/docs/transforms/identifier/index.html
# removing sidebar from  vega-docs/docs/transforms/stratify/index.html
# removing sidebar from  vega-docs/docs/transforms/treelinks/index.html
# removing sidebar from  vega-docs/docs/transforms/window/index.html
# removing sidebar from  vega-docs/docs/transforms/loess/index.html
# removing sidebar from  vega-docs/docs/transforms/formula/index.html
# removing sidebar from  vega-docs/docs/transforms/sample/index.html
# removing sidebar from  vega-docs/docs/transforms/crossfilter/index.html
# removing sidebar from  vega-docs/docs/transforms/fold/index.html
# removing sidebar from  vega-docs/docs/transforms/wordcloud/index.html
# removing sidebar from  vega-docs/docs/transforms/heatmap/index.html
# removing sidebar from  vega-docs/docs/transforms/geopath/index.html
# removing sidebar from  vega-docs/docs/transforms/stack/index.html
# removing sidebar from  vega-docs/docs/transforms/filter/index.html
# removing sidebar from  vega-docs/docs/transforms/partition/index.html
# removing sidebar from  vega-docs/docs/transforms/regression/index.html
# removing sidebar from  vega-docs/docs/transforms/sequence/index.html
# removing sidebar from  vega-docs/docs/transforms/force/index.html
# removing sidebar from  vega-docs/docs/transforms/treemap/index.html
# removing sidebar from  vega-docs/docs/transforms/nest/index.html
# removing sidebar from  vega-docs/docs/transforms/isocontour/index.html
# removing sidebar from  vega-docs/docs/expressions/index.html
# removing sidebar from  vega-docs/docs/api/statistics/index.html
# removing sidebar from  vega-docs/docs/api/locale/index.html
# removing sidebar from  vega-docs/docs/api/util/index.html
# removing sidebar from  vega-docs/docs/api/debugging/index.html
# removing sidebar from  vega-docs/docs/api/parser/index.html
# removing sidebar from  vega-docs/docs/api/time/index.html
# removing sidebar from  vega-docs/docs/api/view/index.html
# removing sidebar from  vega-docs/docs/api/extensibility/index.html
# removing sidebar from  vega-docs/docs/data/index.html

# %%
from urllib.parse import urlparse

# %%
#urlparse('../../foobar/index.html#specification')

# %%
# tack on HTML paths
def update_html_paths(filename):
    with open(filename) as fp:
        text = fp.read()

    # remove sidebar nav elements
    soup = BeautifulSoup(text, 'lxml')
    links = soup.findAll('a')

    if links is None:
      return text

    numUpdated = 0
  
    for link in links:
      ref = link.get('href')

      # if ref and "CODE_OF_CONDUCT" in ref:
      #   print(ref)

        
      if ref and not "https://" in ref and ref.endswith('/'):
        link['href'] = ref + 'index.html'
        numUpdated += 1
      elif ref and ref.startswith('file:/') and not ref.endswith('.json'):
        pass # ignore schema updates
      elif ref and ref.startswith('#'):
        pass # ignore self links
      elif ref and not 'http' in ref and not (ref.endswith('.html') or ref.endswith('.md')):
        # link['href'] = ref + '/index.html'
        parsed = urlparse(ref)
        
        if parsed.fragment:
          subpath = parsed.path + 'index.html' if parsed.path.endswith('/') else parsed.path + '/index.html'
          link['href'] = subpath + f"#{parsed.fragment}"
        else:
          link['href'] = ref + '/index.html'

        numUpdated += 1

      # if ref and "CODE_OF_CONDUCT" in ref:
      #   print(link['href'])

    print(f"updated {numUpdated}")
    
    return str(soup)

# %%
# updated 
matches = glob.glob(f"vega-docs/**/*.html", recursive=True)
print(len(matches))

for name in matches:
    if DEBUG:
        print('Update HTML paths', name)
    processed = update_html_paths(name)
    
    with open(name, 'w') as fp:
        fp.write(processed)
# Out:
# 192
# Update HTML paths vega-docs/index.html
# updated 19
# Update HTML paths vega-docs/usage/index.html
# updated 12
# Update HTML paths vega-docs/usage/interpreter/index.html
# updated 6
# Update HTML paths vega-docs/usage/internet-explorer/index.html
# updated 7
# Update HTML paths vega-docs/about/index.html
# updated 11
# Update HTML paths vega-docs/about/research/index.html
# updated 6
# Update HTML paths vega-docs/about/video/index.html
# updated 6
# Update HTML paths vega-docs/about/projects/index.html
# updated 10
# Update HTML paths vega-docs/about/vega-and-d3/index.html
# updated 8
# Update HTML paths vega-docs/about/code-of-conduct/index.html
# updated 6
# Update HTML paths vega-docs/docs/index.html
# updated 43
# Update HTML paths vega-docs/docs/schemes/index.html
# updated 73
# Update HTML paths vega-docs/docs/event-streams/index.html
# updated 22
# Update HTML paths vega-docs/docs/types/index.html
# updated 51
# Update HTML paths vega-docs/docs/axes/index.html
# updated 111
# Update HTML paths vega-docs/docs/marks/index.html
# updated 59
# Update HTML paths vega-docs/docs/marks/shape/index.html
# updated 36
# Update HTML paths vega-docs/docs/marks/rect/index.html
# updated 39
# Update HTML paths vega-docs/docs/marks/trail/index.html
# updated 36
# Update HTML paths vega-docs/docs/marks/area/index.html
# updated 38
# Update HTML paths vega-docs/docs/marks/group/index.html
# updated 49
# Update HTML paths vega-docs/docs/marks/path/index.html
# updated 38
# Update HTML paths vega-docs/docs/marks/symbol/index.html
# updated 37
# Update HTML paths vega-docs/docs/marks/image/index.html
# updated 39
# Update HTML paths vega-docs/docs/marks/rule/index.html
# updated 34
# Update HTML paths vega-docs/docs/marks/line/index.html
# updated 37
# Update HTML paths vega-docs/docs/marks/text/index.html
# updated 53
# Update HTML paths vega-docs/docs/marks/arc/index.html
# updated 40
# Update HTML paths vega-docs/docs/legends/index.html
# updated 105
# Update HTML paths vega-docs/docs/config/index.html
# updated 234
# Update HTML paths vega-docs/docs/title/index.html
# updated 52
# Update HTML paths vega-docs/docs/triggers/index.html
# updated 15
# Update HTML paths vega-docs/docs/porting-guide/index.html
# updated 10
# Update HTML paths vega-docs/docs/layout/index.html
# updated 25
# Update HTML paths vega-docs/docs/signals/index.html
# updated 39
# Update HTML paths vega-docs/docs/projections/index.html
# updated 27
# Update HTML paths vega-docs/docs/specification/index.html
# updated 42
# Update HTML paths vega-docs/docs/scales/index.html
# updated 86
# Update HTML paths vega-docs/docs/transforms/index.html
# updated 62
# Update HTML paths vega-docs/docs/transforms/tree/index.html
# updated 16
# Update HTML paths vega-docs/docs/transforms/joinaggregate/index.html
# updated 12
# Update HTML paths vega-docs/docs/transforms/geojson/index.html
# updated 9
# Update HTML paths vega-docs/docs/transforms/collect/index.html
# updated 7
# Update HTML paths vega-docs/docs/transforms/pivot/index.html
# updated 14
# Update HTML paths vega-docs/docs/transforms/geoshape/index.html
# updated 14
# Update HTML paths vega-docs/docs/transforms/bin/index.html
# updated 20
# Update HTML paths vega-docs/docs/transforms/linkpath/index.html
# updated 16
# Update HTML paths vega-docs/docs/transforms/quantile/index.html
# updated 12
# Update HTML paths vega-docs/docs/transforms/resolvefilter/index.html
# updated 12
# Update HTML paths vega-docs/docs/transforms/aggregate/index.html
# updated 14
# Update HTML paths vega-docs/docs/transforms/contour/index.html
# updated 21
# Update HTML paths vega-docs/docs/transforms/cross/index.html
# updated 8
# Update HTML paths vega-docs/docs/transforms/geopoint/index.html
# updated 11
# Update HTML paths vega-docs/docs/transforms/pack/index.html
# updated 15
# Update HTML paths vega-docs/docs/transforms/label/index.html
# updated 23
# Update HTML paths vega-docs/docs/transforms/density/index.html
# updated 24
# Update HTML paths vega-docs/docs/transforms/timeunit/index.html
# updated 15
# Update HTML paths vega-docs/docs/transforms/lookup/index.html
# updated 12
# Update HTML paths vega-docs/docs/transforms/impute/index.html
# updated 12
# Update HTML paths vega-docs/docs/transforms/graticule/index.html
# updated 16
# Update HTML paths vega-docs/docs/transforms/countpattern/index.html
# updated 11
# Update HTML paths vega-docs/docs/transforms/pie/index.html
# updated 12
# Update HTML paths vega-docs/docs/transforms/extent/index.html
# updated 9
# Update HTML paths vega-docs/docs/transforms/project/index.html
# updated 9
# Update HTML paths vega-docs/docs/transforms/kde/index.html
# updated 18
# Update HTML paths vega-docs/docs/transforms/kde2d/index.html
# updated 20
# Update HTML paths vega-docs/docs/transforms/voronoi/index.html
# updated 12
# Update HTML paths vega-docs/docs/transforms/dotbin/index.html
# updated 15
# Update HTML paths vega-docs/docs/transforms/flatten/index.html
# updated 11
# Update HTML paths vega-docs/docs/transforms/identifier/index.html
# updated 7
# Update HTML paths vega-docs/docs/transforms/stratify/index.html
# updated 12
# Update HTML paths vega-docs/docs/transforms/treelinks/index.html
# updated 8
# Update HTML paths vega-docs/docs/transforms/window/index.html
# updated 20
# Update HTML paths vega-docs/docs/transforms/loess/index.html
# updated 12
# Update HTML paths vega-docs/docs/transforms/formula/index.html
# updated 10
# Update HTML paths vega-docs/docs/transforms/sample/index.html
# updated 7
# Update HTML paths vega-docs/docs/transforms/crossfilter/index.html
# updated 11
# Update HTML paths vega-docs/docs/transforms/fold/index.html
# updated 10
# Update HTML paths vega-docs/docs/transforms/wordcloud/index.html
# updated 26
# Update HTML paths vega-docs/docs/transforms/heatmap/index.html
# updated 16
# Update HTML paths vega-docs/docs/transforms/geopath/index.html
# updated 16
# Update HTML paths vega-docs/docs/transforms/stack/index.html
# updated 12
# Update HTML paths vega-docs/docs/transforms/filter/index.html
# updated 8
# Update HTML paths vega-docs/docs/transforms/partition/index.html
# updated 15
# Update HTML paths vega-docs/docs/transforms/regression/index.html
# updated 15
# Update HTML paths vega-docs/docs/transforms/sequence/index.html
# updated 11
# Update HTML paths vega-docs/docs/transforms/force/index.html
# updated 45
# Update HTML paths vega-docs/docs/transforms/treemap/index.html
# updated 23
# Update HTML paths vega-docs/docs/transforms/nest/index.html
# updated 13
# Update HTML paths vega-docs/docs/transforms/isocontour/index.html
# updated 21
# Update HTML paths vega-docs/docs/expressions/index.html
# updated 20
# Update HTML paths vega-docs/docs/api/statistics/index.html
# updated 6
# Update HTML paths vega-docs/docs/api/locale/index.html
# updated 8
# Update HTML paths vega-docs/docs/api/util/index.html
# updated 7
# Update HTML paths vega-docs/docs/api/debugging/index.html
# updated 16
# Update HTML paths vega-docs/docs/api/parser/index.html
# updated 11
# Update HTML paths vega-docs/docs/api/time/index.html
# updated 7
# Update HTML paths vega-docs/docs/api/view/index.html
# updated 8
# Update HTML paths vega-docs/docs/api/extensibility/index.html
# updated 13
# Update HTML paths vega-docs/docs/data/index.html
# updated 33
# Update HTML paths vega-docs/examples/index.html
# updated 94
# Update HTML paths vega-docs/examples/arc-diagram/index.html
# updated 8
# Update HTML paths vega-docs/examples/platformer/index.html
# updated 9
# Update HTML paths vega-docs/examples/histogram-null-values/index.html
# updated 9
# Update HTML paths vega-docs/examples/world-map/index.html
# updated 11
# Update HTML paths vega-docs/examples/pacman/index.html
# updated 8
# Update HTML paths vega-docs/examples/falkensee-population/index.html
# updated 8
# Update HTML paths vega-docs/examples/error-bars/index.html
# updated 8
# Update HTML paths vega-docs/examples/overview-plus-detail/index.html
# updated 8
# Update HTML paths vega-docs/examples/edge-bundling/index.html
# updated 11
# Update HTML paths vega-docs/examples/connected-scatter-plot/index.html
# updated 8
# Update HTML paths vega-docs/examples/wheat-and-wages/index.html
# updated 8
# Update HTML paths vega-docs/examples/zoomable-circle-packing/index.html
# updated 9
# Update HTML paths vega-docs/examples/word-cloud/index.html
# updated 11
# Update HTML paths vega-docs/examples/u-district-cuisine/index.html
# updated 10
# Update HTML paths vega-docs/examples/scatter-plot-null-values/index.html
# updated 9
# Update HTML paths vega-docs/examples/zoomable-world-map/index.html
# updated 9
# Update HTML paths vega-docs/examples/annual-precipitation/index.html
# updated 8
# Update HTML paths vega-docs/examples/crossfilter-flights/index.html
# updated 10
# Update HTML paths vega-docs/examples/wheat-plot/index.html
# updated 9
# Update HTML paths vega-docs/examples/violin-plot/index.html
# updated 9
# Update HTML paths vega-docs/examples/flight-passengers/index.html
# updated 8
# Update HTML paths vega-docs/examples/stock-index-chart/index.html
# updated 8
# Update HTML paths vega-docs/examples/circle-packing/index.html
# updated 9
# Update HTML paths vega-docs/examples/reorderable-matrix/index.html
# updated 8
# Update HTML paths vega-docs/examples/pie-chart/index.html
# updated 8
# Update HTML paths vega-docs/examples/top-k-plot/index.html
# updated 9
# Update HTML paths vega-docs/examples/labeled-scatter-plot/index.html
# updated 9
# Update HTML paths vega-docs/examples/stacked-area-chart/index.html
# updated 8
# Update HTML paths vega-docs/examples/bar-chart/index.html
# updated 9
# Update HTML paths vega-docs/examples/population-pyramid/index.html
# updated 8
# Update HTML paths vega-docs/examples/global-development/index.html
# updated 8
# Update HTML paths vega-docs/examples/serpentine-timeline/index.html
# updated 8
# Update HTML paths vega-docs/examples/annual-temperature/index.html
# updated 9
# Update HTML paths vega-docs/examples/projections/index.html
# updated 9
# Update HTML paths vega-docs/examples/top-k-plot-with-others/index.html
# updated 10
# Update HTML paths vega-docs/examples/timelines/index.html
# updated 8
# Update HTML paths vega-docs/examples/quantile-dot-plot/index.html
# updated 10
# Update HTML paths vega-docs/examples/binned-scatter-plot/index.html
# updated 9
# Update HTML paths vega-docs/examples/box-plot/index.html
# updated 9
# Update HTML paths vega-docs/examples/grouped-bar-chart/index.html
# updated 8
# Update HTML paths vega-docs/examples/tree-layout/index.html
# updated 9
# Update HTML paths vega-docs/examples/pi-monte-carlo/index.html
# updated 8
# Update HTML paths vega-docs/examples/time-units/index.html
# updated 11
# Update HTML paths vega-docs/examples/county-unemployment/index.html
# updated 9
# Update HTML paths vega-docs/examples/hypothetical-outcome-plots/index.html
# updated 8
# Update HTML paths vega-docs/examples/radar-chart/index.html
# updated 8
# Update HTML paths vega-docs/examples/parallel-coordinates/index.html
# updated 8
# Update HTML paths vega-docs/examples/barley-trellis-plot/index.html
# updated 8
# Update HTML paths vega-docs/examples/density-heatmaps/index.html
# updated 13
# Update HTML paths vega-docs/examples/stacked-bar-chart/index.html
# updated 8
# Update HTML paths vega-docs/examples/contour-plot/index.html
# updated 11
# Update HTML paths vega-docs/examples/force-directed-layout/index.html
# updated 9
# Update HTML paths vega-docs/examples/quantile-quantile-plot/index.html
# updated 11
# Update HTML paths vega-docs/examples/budget-forecasts/index.html
# updated 8
# Update HTML paths vega-docs/examples/brushing-scatter-plots/index.html
# updated 8
# Update HTML paths vega-docs/examples/area-chart/index.html
# updated 8
# Update HTML paths vega-docs/examples/zoomable-binned-plot/index.html
# updated 8
# Update HTML paths vega-docs/examples/zoomable-scatter-plot/index.html
# updated 8
# Update HTML paths vega-docs/examples/line-chart/index.html
# updated 8
# Update HTML paths vega-docs/examples/distortion-comparison/index.html
# updated 10
# Update HTML paths vega-docs/examples/weekly-temperature/index.html
# updated 8
# Update HTML paths vega-docs/examples/watch/index.html
# updated 9
# Update HTML paths vega-docs/examples/heatmap/index.html
# updated 12
# Update HTML paths vega-docs/examples/dot-plot/index.html
# updated 11
# Update HTML paths vega-docs/examples/probability-density/index.html
# updated 9
# Update HTML paths vega-docs/examples/warming-stripes/index.html
# updated 8
# Update HTML paths vega-docs/examples/horizon-graph/index.html
# updated 9
# Update HTML paths vega-docs/examples/regression/index.html
# updated 9
# Update HTML paths vega-docs/examples/volcano-contours/index.html
# updated 8
# Update HTML paths vega-docs/examples/radial-plot/index.html
# updated 8
# Update HTML paths vega-docs/examples/sunburst/index.html
# updated 11
# Update HTML paths vega-docs/examples/loess-regression/index.html
# updated 9
# Update HTML paths vega-docs/examples/calendar-view/index.html
# updated 8
# Update HTML paths vega-docs/examples/interactive-legend/index.html
# updated 8
# Update HTML paths vega-docs/examples/job-voyager/index.html
# updated 8
# Update HTML paths vega-docs/examples/scatter-plot/index.html
# updated 8
# Update HTML paths vega-docs/examples/beeswarm-plot/index.html
# updated 9
# Update HTML paths vega-docs/examples/treemap/index.html
# updated 8
# Update HTML paths vega-docs/examples/wind-vectors/index.html
# updated 8
# Update HTML paths vega-docs/examples/nested-bar-chart/index.html
# updated 8
# Update HTML paths vega-docs/examples/radial-tree-layout/index.html
# updated 9
# Update HTML paths vega-docs/examples/clock/index.html
# updated 8
# Update HTML paths vega-docs/examples/packed-bubble-chart/index.html
# updated 8
# Update HTML paths vega-docs/examples/earthquakes/index.html
# updated 9
# Update HTML paths vega-docs/examples/histogram/index.html
# updated 8
# Update HTML paths vega-docs/examples/dorling-cartogram/index.html
# updated 10
# Update HTML paths vega-docs/examples/airport-connections/index.html
# updated 9
# Update HTML paths vega-docs/examples/donut-chart/index.html
# updated 8
# Update HTML paths vega-docs/tutorials/index.html
# updated 8
# Update HTML paths vega-docs/tutorials/bar-chart/index.html
# updated 20
# Update HTML paths vega-docs/tutorials/airports/index.html
# updated 22

# %%
# Move HTML into the right directory
#!rsync -r ../vega-lite/site/_site/* ./vega-lite-docs
# exclude static data files since dash doesn't run a local fileserver
# !rsync -r ./vega-docs/* $DOCSET_PATH \
     --exclude 'data/*.csv' --exclude 'data/*.arrow' --exclude 'data/*.json' --exclude 'data/*.tsv' \
     --exclude 'sitemap.xml' --exclude '*min.js.map' --exclude 'rollup.config.js' --exclude 'releases/' --exclude 'robots.txt' --exclude 'vega-schema.json'

# %%
# !mkdir ../Dash-User-Contributions/docsets/Vega/

# %%
# Prepare to publish in adjacent user contribs repository
# !tar --exclude='.DS_Store' -cvzf vega.tgz vega.docset
# !cp vega.tgz ../Dash-User-Contributions/docsets/Vega/
